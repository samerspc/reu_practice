# %%
from google.colab import drive
import os
import zipfile

# Подключаем Google Drive
drive.mount('/content/drive')

# Путь к архиву
zip_path = '/content/drive/MyDrive/archive.zip'
extract_dir = '/content/food_dataset'

# Распаковываем
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print("Датасет успешно распакован!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Датасет успешно распакован!

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

source_dir = '/content/food_dataset/images'
output_dir = '/content/food_dataset_processed'

os.makedirs(output_dir, exist_ok=True)
for folder in ['train', 'val', 'test']:
    os.makedirs(os.path.join(output_dir, folder), exist_ok=True)

# Разделим данные: 70% train, 15% val, 15% test
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)
    if os.path.isdir(class_path):
        images = os.listdir(class_path)
        train_files, test_val_files = train_test_split(images, test_size=0.3, random_state=42)
        val_files, test_files = train_test_split(test_val_files, test_size=0.5, random_state=42)

        for img in train_files:
            src = os.path.join(class_path, img)
            dst = os.path.join(output_dir, 'train', class_name)
            os.makedirs(dst, exist_ok=True)
            shutil.copy(src, dst)

        for img in val_files:
            src = os.path.join(class_path, img)
            dst = os.path.join(output_dir, 'val', class_name)
            os.makedirs(dst, exist_ok=True)
            shutil.copy(src, dst)

        for img in test_files:
            src = os.path.join(class_path, img)
            dst = os.path.join(output_dir, 'test', class_name)
            os.makedirs(dst, exist_ok=True)
            shutil.copy(src, dst)

print("Разделение на train/val/test выполнено!")
# Out:
# Разделение на train/val/test выполнено!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 128  # Уменьшаем размер для экономии памяти
BATCH_SIZE = 32

# Аугментация для тренировочных данных
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Только нормализация для валидации
val_datagen = ImageDataGenerator(rescale=1./255)

# Генераторы
train_gen = train_datagen.flow_from_directory(
    os.path.join(output_dir, 'train'),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    os.path.join(output_dir, 'val'),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Классы: {train_gen.num_classes}")
# Out:
# Found 70700 images belonging to 101 classes.
# Found 15150 images belonging to 101 classes.
# Классы: 101

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# Загружаем предобученную MobileNetV2 без верхних слоев
IMG_SIZE = 128
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# Замораживаем базовую модель
base_model.trainable = False

# Добавляем свои слои
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(train_gen.num_classes, activation='softmax')(x)

# Собираем модель
model = Model(inputs=base_model.input, outputs=predictions)

# Компилируем
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Модель создана!")
model.summary()
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Модель создана!
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ...

# %%
# Callbacks
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=3, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.2, patience=2)
]

# Обучаем только новые слои
history = model.fit(
    train_gen,
    epochs=15,
    validation_data=val_gen,
    callbacks=callbacks
)

# Сохраняем промежуточную модель
model.save('/content/model_mobilenet_stage1.h5')
print("Первый этап обучения завершён и модель сохранена.")
# Out:
# Epoch 1/15
# 2210/2210 ━━━━━━━━━━━━━━━━━━━━ 1530s 692ms/step - accuracy: 0.2603 - loss: 3.1802 - val_accuracy: 0.4068 - val_loss: 2.3922 - learning_rate: 0.0010
# Epoch 2/15
# 2210/2210 ━━━━━━━━━━━━━━━━━━━━ 1567s 709ms/step - accuracy: 0.4041 - loss: 2.4030 - val_accuracy: 0.4226 - val_loss: 2.2958 - learning_rate: 0.0010
# Epoch 3/15
# 2210/2210 ━━━━━━━━━━━━━━━━━━━━ 1645s 744ms/step - accuracy: 0.4256 - loss: 2.2928 - val_accuracy: 0.4371 - val_loss: 2.2601 - learning_rate: 0.0010
# Epoch 4/15
# 2210/2210 ━━━━━━━━━━━━━━━━━━━━ 1648s 745ms/step - accuracy: 0.4388 - loss: 2.2276 - val_accuracy: 0.4402 - val_loss: 2.2537 - learning_rate: 0.0010
# Epoch 5/15
# 2210/2210 ━━━━━━━━━━━━━━━━━━━━ 1624s 735ms/step - accuracy: 0.4473 - loss: 2.1941 - val_accuracy: 0.4475 - val_loss: 2.2346 - learning_rate: 0.0010
# Epoch 6/15
# 2210/2210 ━━━━━━━━━━━━━━━━━━━━ 1685s 763ms/step - accuracy: 0.4533 - loss: 2.1551 - val_accuracy: 0.4460 - val_loss: 2.2561 - learning_rate: 0.0010
# Epoch 7/15
# ...

# %%
# ✅ Добавляем недостающий импорт
import tensorflow as tf

# Размораживаем последние N слоёв
for layer in base_model.layers[-20:]:
    layer.trainable = True

# Перекомпилируем с меньшим learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Продолжаем обучение
history_fine = model.fit(
    train_gen,
    epochs=10,
    validation_data=val_gen,
    callbacks=callbacks,
    initial_epoch=history.epoch[-1]  # Продолжаем от предыдущего этапа
)

# Сохраняем финальную модель
model.save('/content/model_mobilenet_final.h5')
print("Второй этап дообучения завершён. Модель готова к экспорту.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Второй этап дообучения завершён. Модель готова к экспорту.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Путь к сохранённой модели
model = tf.keras.models.load_model('/content/model_mobilenet_final.h5')

# Путь к твоему изображению (можно загрузить через Colab)
uploaded_image_path = '/content/piz.jpg'

# ❗Загрузи своё изображение через Colab:
from google.colab import files
uploaded = files.upload()

# Сохрани загруженное изображение локально
import os
for fn in uploaded.keys():
    uploaded_image_path = fn
    print(f"Файл {fn} сохранён по пути: {uploaded_image_path}")

# Размер изображения, использованный при обучении
IMG_SIZE = 128

# Предобработка изображения
img = image.load_img(uploaded_image_path, target_size=(IMG_SIZE, IMG_SIZE))
img_array = image.img_to_array(img) / 255.0  # Нормализация
img_array = np.expand_dims(img_array, axis=0)  # Добавляем batch dimension

# Предсказание
preds = model.predict(img_array)
predicted_class_index = np.argmax(preds, axis=1)[0]

# Получаем список классов из генератора (предположим, что ты сохранил train_gen)
class_indices = train_gen.class_indices
class_labels = list(class_indices.keys())

# Вывод результата
print(f"\nПредсказанный класс: {class_labels[predicted_class_index]}")
print(f"Вероятности: {preds[0][predicted_class_index]:.4f}")

# Отображаем изображение
plt.imshow(img)
plt.title(f"Предсказание: {class_labels[predicted_class_index]}")
plt.axis('off')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#      <input type="file" id="files-bba36973-49f8-41b8-ae64-0d844336c83e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bba36973-49f8-41b8-ae64-0d844336c83e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, accuracy_score

# Путь к обученной модели
model = tf.keras.models.load_model('/content/model_mobilenet_final.h5')

# Параметры
IMG_SIZE = 128
BATCH_SIZE = 32
TEST_DIR = '/content/food_dataset_processed/test'

# Генератор для тестовой выборки
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Получаем истинные метки
y_true = test_generator.classes

# Предсказываем
preds = model.predict(test_generator)
y_pred = np.argmax(preds, axis=1)

# Список классов
class_labels = list(test_generator.class_indices.keys())

# Выводим общую accuracy
print(f"Общая Accuracy: {accuracy_score(y_true, y_pred):.4f}\n")

# Выводим подробный отчет по классам
print("Метрики по классам:")
print(classification_report(y_true, y_pred, target_names=class_labels, digits=4))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 15150 images belonging to 101 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 219s 457ms/step
# Общая Accuracy: 0.5350
#
# Метрики по классам:
#                          precision    recall  f1-score   support
#
#               apple_pie     0.4725    0.2867    0.3568       150
#          baby_back_ribs     0.4719    0.5600    0.5122       150
#                 baklava     0.6220    0.5267    0.5704       150
# ...

# %%
print('fff')
# Out:
# fff
